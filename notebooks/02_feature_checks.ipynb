# %% [markdown]
# # Feature Engineering Validation
#
# This notebook validates engineered features to ensure:
# - No label leakage (features use only pre-fight information)
# - Feature distributions are sensible
# - No unexpected missing values or outliers
# - Correlation structure makes sense
# - Train/test split maintains temporal consistency

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
from pathlib import Path

# Add src to path
sys.path.insert(0, str(Path.cwd().parent / "src"))

from ufc_predictor import config

# %matplotlib inline
plt.style.use('seaborn-v0_8-darkgrid')

# %% [markdown]
# ## 1. Load Engineered Features
#
# TODO: Load feature matrices from data/features/

# %%
# TODO: Load features
# X_train = pd.read_parquet(config.FEATURES_DATA_DIR / "features_train.parquet")
# X_test = pd.read_parquet(config.FEATURES_DATA_DIR / "features_test.parquet")

# %% [markdown]
# ## 2. Label Leakage Check
#
# TODO: Verify temporal consistency and no future information in features

# %%
# TODO: Check for label leakage
# - Verify train dates < test dates
# - Check that historical features don't include current fight

# %% [markdown]
# ## 3. Feature Distributions
#
# TODO: Plot distributions of key features

# %%
# TODO: Feature distribution plots

# %% [markdown]
# ## 4. Correlation Analysis
#
# TODO: Compute and visualize feature correlations

# %%
# TODO: Correlation heatmap

# %% [markdown]
# ## 5. Missing Values
#
# TODO: Check for and analyze missing values

# %%
# TODO: Missing value analysis

# %% [markdown]
# ## 6. ELO Feature Validation
#
# TODO: Specifically validate ELO ratings make sense

# %%
# TODO: ELO validation
# - Check distribution of ratings
# - Verify elo_diff correlates with outcomes
# - Plot rating evolution over time for sample fighters
