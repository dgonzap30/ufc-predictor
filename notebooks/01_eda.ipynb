# %% [markdown]
# # UFC Data Exploratory Data Analysis (EDA)
#
# This notebook explores the raw UFC fight data to understand:
# - Data structure and schema
# - Data quality issues
# - Distribution of key variables
# - Temporal patterns
# - Fighter characteristics
# - Fight outcomes and trends

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
from pathlib import Path

# Add src to path
sys.path.insert(0, str(Path.cwd().parent / "src"))

from ufc_predictor import config
from ufc_predictor.data import ingest

# %matplotlib inline
plt.style.use('seaborn-v0_8-darkgrid')

# %% [markdown]
# ## 1. Load Raw Data
#
# TODO: Load raw CSV files using ingestion module

# %%
# TODO: Load data
# fights = ingest.load_raw_fights(...)
# fighters = ingest.load_raw_fighters(...)
# events = ingest.load_raw_events(...)

# %% [markdown]
# ## 2. Data Overview
#
# TODO: Display shape, columns, dtypes, missing values

# %%
# TODO: Explore data structure

# %% [markdown]
# ## 3. Temporal Analysis
#
# TODO: Analyze fights over time, identify temporal trends

# %%
# TODO: Temporal visualizations

# %% [markdown]
# ## 4. Fighter Characteristics
#
# TODO: Analyze height, reach, age, stance distributions

# %%
# TODO: Fighter attribute analysis

# %% [markdown]
# ## 5. Fight Outcomes
#
# TODO: Analyze outcome distributions, method of victory, etc.

# %%
# TODO: Outcome analysis
